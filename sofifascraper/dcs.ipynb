# %% [markdown]
# # The Sofifa Scraper

# %%
import numpy as np
import pandas as pd
import calendar
import matplotlib.pyplot as plt
import math
from datetime import datetime

# %%
pd.set_option('display.max.columns', 30)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max.rows', 1000)
pd.set_option("display.float_format", lambda x: "%.2f" % x )

# %% [markdown]
# ## Load Dataset

# %%
#Load the datset
df = pd.read_csv("./results/player_dataset.csv")

# %%
#Preview the original dataset
df.head(2)
# Out:
#         name                            fullname  \
# 0  K. Mbappé                Kylian Mbappé Lottin
# 1   M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح
#
#                                                         playerData playerPos  \
# 0  ['26', 'Dec', '20', '1998', '182cm', '6\'0"', '81kg', '179lbs']  ST LW LM
# 1  ['33', 'Jun', '15', '1992', '175cm', '5\'9"', '72kg', '159lbs']     RM RW
#
#   playerCountry  overallRating  potential playerValue playerWage preferedFoot  \
# 0        France             91         94     €173.5M      €610K        Right
# 1         Egypt             91         91        €82M      €370K         Left
#
#   releaseClause     clubName          league  clubKitNumber contractStart  \
# 0       €368.7M  Real Madrid         La Liga          10.00   Jul 1, 2024
# 1       €151.7M    Liverpool  Premier League          11.00   Jul 1, 2017
#
#   contractEnd nationalTeam  countryKitNumber  \
# 0        2029       France                10
# 1        2027    Liverpool                11
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
# 1  https://cdn.sofifa.net/players/209/331/26_360.png
#
#                              playerLink
# 0  /player/231747/kylian-mbappe/260006/
# 1  /player/209331/mohamed-salah/260006/

# %% [markdown]
# ### Staging dataset

# %% [markdown]
# The staging dataset is use so as not to alter the original dataset till I full done

# %%
df1 = df.copy()

# %%
df1.head(2)
# Out:
#         name                            fullname  \
# 0  K. Mbappé                Kylian Mbappé Lottin
# 1   M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح
#
#                                                         playerData playerPos  \
# 0  ['26', 'Dec', '20', '1998', '182cm', '6\'0"', '81kg', '179lbs']  ST LW LM
# 1  ['33', 'Jun', '15', '1992', '175cm', '5\'9"', '72kg', '159lbs']     RM RW
#
#   playerCountry  overallRating  potential playerValue playerWage preferedFoot  \
# 0        France             91         94     €173.5M      €610K        Right
# 1         Egypt             91         91        €82M      €370K         Left
#
#   releaseClause     clubName          league  clubKitNumber contractStart  \
# 0       €368.7M  Real Madrid         La Liga          10.00   Jul 1, 2024
# 1       €151.7M    Liverpool  Premier League          11.00   Jul 1, 2017
#
#   contractEnd nationalTeam  countryKitNumber  \
# 0        2029       France                10
# 1        2027    Liverpool                11
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
# 1  https://cdn.sofifa.net/players/209/331/26_360.png
#
#                              playerLink
# 0  /player/231747/kylian-mbappe/260006/
# 1  /player/209331/mohamed-salah/260006/

# %% [markdown]
# ## Overview

# %%
df1.head(2)
# Out:
#         name                            fullname  \
# 0  K. Mbappé                Kylian Mbappé Lottin
# 1   M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح
#
#                                                         playerData playerPos  \
# 0  ['26', 'Dec', '20', '1998', '182cm', '6\'0"', '81kg', '179lbs']  ST LW LM
# 1  ['33', 'Jun', '15', '1992', '175cm', '5\'9"', '72kg', '159lbs']     RM RW
#
#   playerCountry  overallRating  potential playerValue playerWage preferedFoot  \
# 0        France             91         94     €173.5M      €610K        Right
# 1         Egypt             91         91        €82M      €370K         Left
#
#   releaseClause     clubName          league  clubKitNumber contractStart  \
# 0       €368.7M  Real Madrid         La Liga          10.00   Jul 1, 2024
# 1       €151.7M    Liverpool  Premier League          11.00   Jul 1, 2017
#
#   contractEnd nationalTeam  countryKitNumber  \
# 0        2029       France                10
# 1        2027    Liverpool                11
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
# 1  https://cdn.sofifa.net/players/209/331/26_360.png
#
#                              playerLink
# 0  /player/231747/kylian-mbappe/260006/
# 1  /player/209331/mohamed-salah/260006/

# %%
df1.shape
# Out:
# (1500, 20)

# %%
df1.dtypes
# Out:
# name                 object
# fullname             object
# playerData           object
# playerPos            object
# playerCountry        object
# overallRating         int64
# potential             int64
# playerValue          object
# playerWage           object
# preferedFoot         object
# releaseClause        object
# clubName             object
# league               object
# clubKitNumber       float64
# contractStart        object
# contractEnd          object
# nationalTeam         object
# countryKitNumber      int64
# profileImg           object
# playerLink           object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
base_url = "https://sofifa.com"

# %%
#Cleaning the name and the fullname
df1['Name'] = df1['Name'].str.strip()
df1['Fullname'] = df1['Fullname'].str.strip()

# %%
# Cleaning the playerData
df1['playerData'] = df1['playerData'].str.replace("[", "").str.replace("]", "").str.replace("'", "").str.replace("'", "")
df1[['Age', 'BirthMonth', 'BirthDay', 'BirthYear', 'Height CM', 'Height Foot Inches', 'Weight KG', 'Weight Pounds']] = df1['playerData'].str.split(", ", expand = True)
df1.head(1)
# Out:
#         name               fullname  \
# 0  K. Mbappé   Kylian Mbappé Lottin
#
#                                      playerData playerPos playerCountry  \
# 0  26, Dec, 20, 1998, 182cm, 6\0", 81kg, 179lbs  ST LW LM        France
#
#    overallRating  potential playerValue playerWage preferedFoot releaseClause  \
# 0             91         94     €173.5M      €610K        Right       €368.7M
#
#       clubName   league  clubKitNumber contractStart contractEnd nationalTeam  \
# 0  Real Madrid  La Liga          10.00   Jul 1, 2024        2029       France
#
#    countryKitNumber                                         profileImg  \
# 0                10  https://cdn.sofifa.net/players/231/747/26_360.png
#
#                              playerLink Age BirthMonth BirthDay BirthYear  \
# 0  /player/231747/kylian-mbappe/260006/  26        Dec       20      1998
#
#   Height CM Height Foot Inches Weight KG Weight Pounds
# 0     182cm               6\0"      81kg        179lbs

# %%
df1.columns
# Out:
# Index(['name', 'fullname', 'playerData', 'playerPos', 'playerCountry',
#        'overallRating', 'potential', 'playerValue', 'playerWage',
#        'preferedFoot', 'releaseClause', 'clubName', 'league', 'clubKitNumber',
#        'contractStart', 'contractEnd', 'nationalTeam', 'countryKitNumber',
#        'profileImg', 'playerLink', 'Age', 'BirthMonth', 'BirthDay',
#        'BirthYear', 'Height CM', 'Height Foot Inches', 'Weight KG',
#        'Weight Pounds'],
#       dtype='object')

# %%
#Rearranging 
df1 = df1[['name', 'fullname', 'Age', 'BirthMonth', 'BirthDay',
       'BirthYear', 'Height CM', 'Height Foot Inches', 'Weight KG',
       'Weight Pounds', 'playerPos', 
       'overallRating', 'potential', 'playerValue', 'playerWage',
       'releaseClause', 'clubName', 'league', 'clubKitNumber',
       'contractStart', 'contractEnd', 'playerCountry', 'nationalTeam', 'countryKitNumber',
       'profileImg', 'playerLink']]

df1.head(1)
# Out:
#         name               fullname Age BirthMonth BirthDay BirthYear  \
# 0  K. Mbappé   Kylian Mbappé Lottin  26        Dec       20      1998
#
#   Height CM Height Foot Inches Weight KG Weight Pounds playerPos  \
# 0     182cm               6\0"      81kg        179lbs  ST LW LM
#
#    overallRating  potential playerValue playerWage releaseClause     clubName  \
# 0             91         94     €173.5M      €610K       €368.7M  Real Madrid
#
#     league  clubKitNumber contractStart contractEnd playerCountry  \
# 0  La Liga          10.00   Jul 1, 2024        2029        France
#
#   nationalTeam  countryKitNumber  \
# 0       France                10
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
#
#                              playerLink
# 0  /player/231747/kylian-mbappe/260006/

# %%
df1.dtypes
# Out:
# name                   object
# fullname               object
# Age                    object
# BirthMonth             object
# BirthDay               object
# BirthYear              object
# Height CM              object
# Height Foot Inches     object
# Weight KG              object
# Weight Pounds          object
# playerPos              object
# overallRating           int64
# potential               int64
# playerValue            object
# playerWage             object
# releaseClause          object
# clubName               object
# league                 object
# clubKitNumber         float64
# contractStart          object
# contractEnd            object
# playerCountry          object
# nationalTeam           object
# countryKitNumber        int64
# profileImg             object
# playerLink             object
# dtype: object

# %%
# Merging the BirthMonth, BirthDay, BirthYear columns to one BirthDate Column
df1.loc[:, 'Birthdate'] = df1['BirthDay'] +"/"+ df1['BirthMonth'] +"/"+ df1['BirthYear']
df1.head(3)
# Out:
#             name                            fullname Age BirthMonth BirthDay  \
# 0      K. Mbappé                Kylian Mbappé Lottin  26        Dec       20
# 1       M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح  33        Jun       15
# 2  J. Bellingham      Jude Victor William Bellingham  22        Jun       29
#
#   BirthYear Height CM Height Foot Inches Weight KG Weight Pounds playerPos  \
# 0      1998     182cm               6\0"      81kg        179lbs  ST LW LM
# 1      1992     175cm               5\9"      72kg        159lbs     RM RW
# 2      2003     186cm               6\1"      75kg        165lbs    CAM CM
#
#    overallRating  potential playerValue playerWage releaseClause     clubName  \
# 0             91         94     €173.5M      €610K       €368.7M  Real Madrid
# 1             91         91        €82M      €370K       €151.7M    Liverpool
# 2             90         94     €174.5M      €320K       €370.8M  Real Madrid
#
#            league  clubKitNumber contractStart contractEnd playerCountry  \
# 0         La Liga          10.00   Jul 1, 2024        2029        France
# 1  Premier League          11.00   Jul 1, 2017        2027         Egypt
# 2         La Liga           5.00   Jul 1, 2023        2029       England
#
#   nationalTeam  countryKitNumber  \
# 0       France                10
# 1    Liverpool                11
# 2      England                10
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
# 1  https://cdn.sofifa.net/players/209/331/26_360.png
# 2  https://cdn.sofifa.net/players/252/371/26_360.png
#
#                                playerLink    Birthdate
# 0    /player/231747/kylian-mbappe/260006/  20/Dec/1998
# 1    /player/209331/mohamed-salah/260006/  15/Jun/1992
# 2  /player/252371/jude-bellingham/260006/  29/Jun/2003

# %%
df1.columns
# Out:
# Index(['name', 'fullname', 'Age', 'BirthMonth', 'BirthDay', 'BirthYear',
#        'Height CM', 'Height Foot Inches', 'Weight KG', 'Weight Pounds',
#        'playerPos', 'overallRating', 'potential', 'playerValue', 'playerWage',
#        'releaseClause', 'clubName', 'league', 'clubKitNumber', 'contractStart',
#        'contractEnd', 'playerCountry', 'nationalTeam', 'countryKitNumber',
#        'profileImg', 'playerLink', 'Birthdate'],
#       dtype='object')

# %%
#Rearranging Columns
df1 = df1[['name', 'fullname', 'Age', 'Birthdate',
       'Height CM', 'Weight KG', 
       'playerPos', 'overallRating', 'potential', 'playerValue', 'playerWage',
       'releaseClause', 'clubName', 'league', 'clubKitNumber', 'contractStart',
       'contractEnd', 'playerCountry', 'nationalTeam', 'countryKitNumber',
       'profileImg', 'playerLink']]

df1.head(3)
# Out:
#             name                            fullname Age    Birthdate  \
# 0      K. Mbappé                Kylian Mbappé Lottin  26  20/Dec/1998
# 1       M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح  33  15/Jun/1992
# 2  J. Bellingham      Jude Victor William Bellingham  22  29/Jun/2003
#
#   Height CM Weight KG playerPos  overallRating  potential playerValue  \
# 0     182cm      81kg  ST LW LM             91         94     €173.5M
# 1     175cm      72kg     RM RW             91         91        €82M
# 2     186cm      75kg    CAM CM             90         94     €174.5M
#
#   playerWage releaseClause     clubName          league  clubKitNumber  \
# 0      €610K       €368.7M  Real Madrid         La Liga          10.00
# 1      €370K       €151.7M    Liverpool  Premier League          11.00
# 2      €320K       €370.8M  Real Madrid         La Liga           5.00
#
#   contractStart contractEnd playerCountry nationalTeam  countryKitNumber  \
# 0   Jul 1, 2024        2029        France       France                10
# 1   Jul 1, 2017        2027         Egypt    Liverpool                11
# 2   Jul 1, 2023        2029       England      England                10
#
#                                           profileImg  \
# 0  https://cdn.sofifa.net/players/231/747/26_360.png
# 1  https://cdn.sofifa.net/players/209/331/26_360.png
# 2  https://cdn.sofifa.net/players/252/371/26_360.png
#
#                                playerLink
# 0    /player/231747/kylian-mbappe/260006/
# 1    /player/209331/mohamed-salah/260006/
# 2  /player/252371/jude-bellingham/260006/

# %%
#Columns to Title_Snake case
df1.columns = df1.columns.str.title().str.replace(" ", "_")
df1.columns
# Out:
# Index(['Name', 'Fullname', 'Age', 'Birthdate', 'Height_Cm', 'Weight_Kg',
#        'Playerpos', 'Overallrating', 'Potential', 'Playervalue', 'Playerwage',
#        'Releaseclause', 'Clubname', 'League', 'Clubkitnumber', 'Contractstart',
#        'Contractend', 'Playercountry', 'Nationalteam', 'Countrykitnumber',
#        'Profileimg', 'Playerlink'],
#       dtype='object')

# %%
# Renaming the column name to a more standard format
df1 = df1.rename (columns = {
    'Weight_Kg' : 'Weight_KG',
    'Height_Cm' : 'Height_CM',
    'Overallrating' : 'OverallRating',
    'Playerpos': 'Position',
    'Playervalue': 'PlayerValue_EUR',
    'Playerwage': 'PlayerWage_EUR',
    'Releaseclause': 'ReleaseClause_EUR',
    'Clubname': 'ClubName',
    'Clubkitnumber': 'ClubKitNumber',
    'Contractstart': 'ContractStart',
    'Contractend': 'ContractEnd',
    'Playercountry': 'Nationality',
    'Nationalteam': 'NationalTeam',
    'Countrykitnumber': 'NationalTeamKitNumber',
    'Profileimg': 'ProfileImg',
    'Playerlink': 'PlayerLink',
})

df1.head(3)
# Out:
#             Name                            Fullname  Age  Birthdate  \
# 0      K. Mbappé                Kylian Mbappé Lottin   26 1998-12-20
# 1       M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح   33 1992-06-15
# 2  J. Bellingham      Jude Victor William Bellingham   22 2003-06-29
#
#    Height_CM  Weight_KG  Position  OverallRating  Potential PlayerValue_EUR  \
# 0        182         81  ST LW LM             91         94         €173.5M
# 1        175         72     RM RW             91         91            €82M
# 2        186         75    CAM CM             90         94         €174.5M
#
#   PlayerWage_EUR ReleaseClause_EUR     ClubName          League  \
# 0          €610K           €368.7M  Real Madrid         La Liga
# 1          €370K           €151.7M    Liverpool  Premier League
# 2          €320K           €370.8M  Real Madrid         La Liga
#
#    ClubKitNumber ContractStart ContractEnd Nationality NationalTeam  \
# 0          10.00   Jul 1, 2024        2029      France       France
# 1          11.00   Jul 1, 2017        2027       Egypt    Liverpool
# 2           5.00   Jul 1, 2023        2029     England      England
#
#    NationalTeamKitNumber                                         ProfileImg  \
# 0                     10  https://cdn.sofifa.net/players/231/747/26_360.png
# 1                     11  https://cdn.sofifa.net/players/209/331/26_360.png
# 2                     10  https://cdn.sofifa.net/players/252/371/26_360.png
#
#                                PlayerLink
# 0    /player/231747/kylian-mbappe/260006/
# 1    /player/209331/mohamed-salah/260006/
# 2  /player/252371/jude-bellingham/260006/

# %%
# Standardizing the Birthdate to datetime dtype
df1['Birthdate'] = pd.to_datetime(df1['Birthdate'])

# The age column to int type
if df1['Age'].dtype == 'O': 
    df1['Age'] = df1['Age'].astype('int64')

# Cleaning the height column
if df1['Height_CM'].dtype == 'O': 
    df1['Height_CM'] = df1['Height_CM'].str.replace("cm", "")
    df1['Height_CM'] = df1['Height_CM'].astype('int64')

# Cleaning the weight column
if df1['Weight_KG'].dtype == 'O': 
    df1['Weight_KG'] = df1['Weight_KG'].str.replace("kg", "")
    df1['Weight_KG'] = df1['Weight_KG'].astype('int64')

# Cleaning the overallRating column
if df1['OverallRating'].dtype == 'O': 
    df1['OverallRating'] = df1['OverallRating'].astype('int64')

# Cleaning the potential column
if df1['Potential'].dtype == 'O': 
    df1['Potential'] = df1['Potential'].astype('int64')

# %%
#Function cleanUpAmountCol - to cleaning up the amount columns
#param: colName - column name
def cleanUpAmountCol(dfr, colName):
    if (dfr[colName].dtype == 'O'):
        # Removing the currency symbol
        dfr.loc[:,colName] = dfr[colName].str.replace("€", "")

        #Cleaning the space character
        dfr.loc[:,colName] = dfr[colName].str.replace(" ", "")
        
        #some of the amount columns contained this string 'Acceleration type Controlled lengthy'
        #this was converted to 0
        dfr.loc[dfr[colName].str.contains("Acceleration"),colName] = "0"
        
        #Converting a M * 1000000
        dfr.loc[dfr[colName].str.contains("M"),colName] = dfr.loc[dfr[colName].str.contains("M"),colName].str.replace("M", "").apply(lambda x: str(float(x) * 1000000))

        #Converting a K * 1000
        dfr.loc[dfr[colName].str.contains("K"),colName] = dfr.loc[dfr[colName].str.contains("K"),colName].str.replace("K", "").apply(lambda x: str(float(x) * 1000))

        # convert the amount column to float
        dfr[colName] = dfr[colName].astype(float)

# %%
# Cleaning the amount columns - PlayerValue_EUR, PlayerWage_EUR, ReleaseClause_EUR
cleanUpAmountCol(df1, "PlayerValue_EUR")
cleanUpAmountCol(df1, "PlayerWage_EUR")
cleanUpAmountCol(df1, "ReleaseClause_EUR")

# %%
# Cleaning the club kit number but leabing it as string
df1['ClubKitNumber'].fillna(0)
df1['ClubKitNumber'] = df1['ClubKitNumber'].apply(lambda x: str(x).split(".")[0])

# %%
# ContractStart, ContractEnd are suppose to be date columns
# but have mixed values of string, int represent year and date
#these columns were converted to string
df1['ContractStart'] = df1['ContractStart'].apply(str)
df1['ContractEnd'] = df1['ContractEnd'].apply(str)

# %%
# THe national team in case where it is empty or haas a club value was converted to the player nationality
df1.loc[:,'NationalTeam'] = np.where(df1['NationalTeam'] == df1['ClubName'], df1['Nationality'], df1['NationalTeam'])

# %%
# Cleaning the nation team kit number
df1['NationalTeamKitNumber'] = df1['NationalTeamKitNumber'].apply(str)

# %%
#Add the base url to the PlayerLink
df1.loc[:,'PlayerLink'] = df1['PlayerLink'].apply(lambda x: f"{base_url}{x}")

# %% [markdown]
# ## Saving result

# %%
df1.head(3)
# Out:
#             Name                            Fullname  Age  Birthdate  \
# 0      K. Mbappé                Kylian Mbappé Lottin   26 1998-12-20
# 1       M. Salah  Mohamed Salah Hamed Ghalyمحمد صلاح   33 1992-06-15
# 2  J. Bellingham      Jude Victor William Bellingham   22 2003-06-29
#
#    Height_CM  Weight_KG  Position  OverallRating  Potential  PlayerValue_EUR  \
# 0        182         81  ST LW LM             91         94     173500000.00
# 1        175         72     RM RW             91         91      82000000.00
# 2        186         75    CAM CM             90         94     174500000.00
#
#    PlayerWage_EUR  ReleaseClause_EUR     ClubName          League  \
# 0       610000.00       368700000.00  Real Madrid         La Liga
# 1       370000.00       151700000.00    Liverpool  Premier League
# 2       320000.00       370800000.00  Real Madrid         La Liga
#
#   ClubKitNumber ContractStart ContractEnd Nationality NationalTeam  \
# 0            10   Jul 1, 2024        2029      France       France
# 1            11   Jul 1, 2017        2027       Egypt        Egypt
# 2             5   Jul 1, 2023        2029     England      England
#
#   NationalTeamKitNumber                                         ProfileImg  \
# 0                    10  https://cdn.sofifa.net/players/231/747/26_360.png
# 1                    11  https://cdn.sofifa.net/players/209/331/26_360.png
# 2                    10  https://cdn.sofifa.net/players/252/371/26_360.png
#
#                                                                    PlayerLink
# 0    https://sofifa.comhttps://sofifa.com/player/231747/kylian-mbappe/260006/
# 1    https://sofifa.comhttps://sofifa.com/player/209331/mohamed-salah/260006/
# 2  https://sofifa.comhttps://sofifa.com/player/252371/jude-bellingham/260006/

# %%
df1.dtypes
# Out:
# Name                             object
# Fullname                         object
# Age                               int64
# Birthdate                datetime64[ns]
# Height_CM                         int64
# Weight_KG                         int64
# Position                         object
# OverallRating                     int64
# Potential                         int64
# PlayerValue_EUR                 float64
# PlayerWage_EUR                  float64
# ReleaseClause_EUR               float64
# ClubName                         object
# League                           object
# ClubKitNumber                    object
# ContractStart                    object
# ContractEnd                      object
# Nationality                      object
# NationalTeam                     object
# NationalTeamKitNumber            object
# ProfileImg                       object
# PlayerLink                       object
# dtype: object

# %%
#Save to file
df1.to_csv("./results/player_dataset_clean.csv")
